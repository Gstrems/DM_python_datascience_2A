# %% [markdown]
# Rendu Intermédiaire Python pour la datascience - Gabriel Stremsdoerfer

# %%
# importation données
import pandas as pd
df = pd.read_csv(
    'https://www.data.gouv.fr/fr/datasets/r/182268fc-2103-4bcb-a850-6cf90b02a9eb'
)
df
# Out:
# /tmp/ipykernel_14521/2336434942.py:3: DtypeWarning: Columns (0: prenom) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
#        code_departement              libelle_departement  code_commune  \
# 0                    01                              Ain             1
# 1                    01                              Ain             2
# 2                    01                              Ain             4
# 3                    01                              Ain             5
# 4                    01                              Ain             6
# ...                 ...                              ...           ...
# 528670      fr_etranger  Français établis hors de France           229
# 528671      fr_etranger  Français établis hors de France           231
# 528672      fr_etranger  Français établis hors de France           233
# 528673      fr_etranger  Français établis hors de France           234
# ...

# %% [markdown]
# 1.Exploration générale

# %%
# Question 1
from code_exo.exo1.Q1 import question_1
question_1(df)
df
# Out:
#        code_departement              libelle_departement    code_commune  \
# 0                    01                              Ain           01001
# 1                    01                              Ain           01002
# 2                    01                              Ain           01004
# 3                    01                              Ain           01005
# 4                    01                              Ain           01006
# ...                 ...                              ...             ...
# 528670      fr_etranger  Français établis hors de France  fr_etranger229
# 528671      fr_etranger  Français établis hors de France  fr_etranger231
# 528672      fr_etranger  Français établis hors de France  fr_etranger233
# 528673      fr_etranger  Français établis hors de France  fr_etranger234
# 528674      fr_etranger  Français établis hors de France  fr_etranger235
#
#                 libelle_commune    prenom      nom  voix          candidat
# ...

# %%
# Question 2
from code_exo.exo1.Q2 import question_2
question_2(df)
# Out:
# "En 2022, il y avait 12 candidats à l'élection présidentielle."

# %%
# Question 3
from great_tables import GT
from code_exo.exo1.Q3 import question_3
table_voix = question_3(df)
(
    GT(table_voix)
    .tab_header(title="Elections", subtitle=f"Résultats du premier tour (10 avril 2022)")
    .fmt_number(columns="Nombre de vote (total)", decimals=0, sep_mark=" ")
    .fmt_percent(columns="Score(% exprimé)", decimals=2)
)
# Out:
# GT(_tbl_data=                 candidat  Nombre de vote (total)  Score(% exprimé)
# 1         Emmanuel MACRON                 9783058          0.278458
# 5           Marine LE PEN                 8133828          0.231516
# 4      Jean-Luc MÉLENCHON                 7712520          0.219524
# 11           Éric ZEMMOUR                 2485226          0.070738
# 9        Valérie PÉCRESSE                 1679001          0.047790
# 10          Yannick JADOT                 1627853          0.046334
# 3           Jean LASSALLE                 1101387          0.031349
# 2          Fabien ROUSSEL                  802422          0.022840
# 7   Nicolas DUPONT-AIGNAN                  725176          0.020641
# 0            Anne HIDALGO                  616478          0.017547
# 8         Philippe POUTOU                  268904          0.007654
# ...

# %% [markdown]
# 2. Comparaison des scores départements aux moyennes nationales

# %%
# Question 4
from code_exo.exo2.Q4 import question_4

score_departements = question_4(df)

(
    GT(score_departements[
        score_departements['code_departement'] == '11'
        ].sort_values(by='votes', ascending = False))
    .fmt_number(columns="votes", decimals=0, sep_mark=" ")
    .fmt_percent(columns="score", decimals=2)
)
# Out:
# GT(_tbl_data=    code_departement               candidat  votes     score
# 125               11          Marine LE PEN  64027  0.301408
# 121               11        Emmanuel MACRON  43104  0.202913
# 124               11     Jean-Luc MÉLENCHON  42039  0.197900
# 131               11           Éric ZEMMOUR  18434  0.086778
# 123               11          Jean LASSALLE  12382  0.058289
# 129               11       Valérie PÉCRESSE   7350  0.034600
# 130               11          Yannick JADOT   6322  0.029761
# 120               11           Anne HIDALGO   6166  0.029027
# 122               11         Fabien ROUSSEL   5622  0.026466
# 127               11  Nicolas DUPONT-AIGNAN   4206  0.019800
# 128               11        Philippe POUTOU   1748  0.008229
# ...

# %%
# Question 5

from code_exo.exo2.Q5 import question_5

score_departements = question_5(score_departements, table_voix)

(
    GT(score_departements[
        score_departements['code_departement'] == '977'
        ].sort_values(by='votes_departement', ascending = False))
    .fmt_number(columns=["votes_departement", "votes_national"], decimals=0, sep_mark=" ")
    .fmt_percent(columns=["score_departement", "score_national"], decimals=2)
)
# Out:
# GT(_tbl_data=     code_departement               candidat  votes_departement  \
# 102               977        Emmanuel MACRON                629
# 210               977          Marine LE PEN                592
# 426               977           Éric ZEMMOUR                469
# 318               977     Jean-Luc MÉLENCHON                348
# 966               977  Nicolas DUPONT-AIGNAN                169
# 534               977       Valérie PÉCRESSE                150
# 642               977          Yannick JADOT                114
# 750               977          Jean LASSALLE                 93
# 1182              977        Philippe POUTOU                 27
# 1074              977           Anne HIDALGO                 27
# 858               977         Fabien ROUSSEL                 14
# 1290              977       Nathalie ARTHAUD                 10
#
#       score_departement  votes_national  score_national
# 102            0.238077         9783058        0.278458
# ...

# %%
# Question 6

from code_exo.exo2.Q6 import question_6

question_6(score_departements)
score_departements.head()
# La variable surrepresentation est une colonne de score_departements
# Out:
#   code_departement         candidat  votes_departement  score_departement  \
# 0               01  Emmanuel MACRON              92206           0.276875
# 1               02  Emmanuel MACRON              58721           0.220872
# 2               03  Emmanuel MACRON              49706           0.267301
# 3               04  Emmanuel MACRON              20800           0.215136
# 4               05  Emmanuel MACRON              20507           0.237804
#
#    votes_national  score_national  surrepresentation
# 0         9783058        0.278458          -0.568589
# 1         9783058        0.278458         -20.680422
# 2         9783058        0.278458          -4.006703
# 3         9783058        0.278458         -22.740273
# 4         9783058        0.278458         -14.599873

# %%
# Question 7

from code_exo.exo2.Q7 import principales_surrepresentations

principales_surrepresentations(score_departements, 'Éric ZEMMOUR')

# %% [markdown]
# 3.Un peu de cartographie

# %%
# Question 8
from cartiflette import carti_download
import matplotlib.pyplot as plt
from code_exo.exo3.Q8 import question_8 

# Chargement des données
departement_borders = carti_download(
            values = ["France"],
            crs = 4326,
            borders = "DEPARTEMENT",
            vectorfile_format="geojson",
            simplification=50,
            filter_by="FRANCE_ENTIERE_DROM_RAPPROCHES",
            source="EXPRESS-COG-CARTO-TERRITOIRE",
            year=2022
            )

question_8(score_departements, departement_borders, "Marine LE PEN")
question_8(score_departements, departement_borders, "Emmanuel MACRON")
question_8(score_departements, departement_borders, "Éric ZEMMOUR")
