# %% [markdown]
# Rendu Intermédiaire Python pour la datascience - Gabriel Stremsdoerfer

# %%
# importation données
import pandas as pd
df = pd.read_csv(
    'https://www.data.gouv.fr/fr/datasets/r/182268fc-2103-4bcb-a850-6cf90b02a9eb'
)
df
# Out:
# /tmp/ipykernel_13946/2336434942.py:3: DtypeWarning: Columns (0: prenom) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
#        code_departement              libelle_departement  code_commune  \
# 0                    01                              Ain             1
# 1                    01                              Ain             2
# 2                    01                              Ain             4
# 3                    01                              Ain             5
# 4                    01                              Ain             6
# ...                 ...                              ...           ...
# 528670      fr_etranger  Français établis hors de France           229
# 528671      fr_etranger  Français établis hors de France           231
# 528672      fr_etranger  Français établis hors de France           233
# 528673      fr_etranger  Français établis hors de France           234
# ...

# %% [markdown]
# 1.Exploration générale

# %%
# Question 1
from code_exo.exo1.Q1 import question_1
question_1(df)
df
# Out:
#        code_departement              libelle_departement code_commune  \
# 0                 01001                              Ain          001
# 1                 01002                              Ain          002
# 2                 01004                              Ain          004
# 3                 01005                              Ain          005
# 4                 01006                              Ain          006
# ...                 ...                              ...          ...
# 528670   fr_etranger229  Français établis hors de France          229
# 528671   fr_etranger231  Français établis hors de France          231
# 528672   fr_etranger233  Français établis hors de France          233
# 528673   fr_etranger234  Français établis hors de France          234
# 528674   fr_etranger235  Français établis hors de France          235
#
#                 libelle_commune    prenom      nom  voix          candidat
# ...

# %%
# Question 2
from code_exo.exo1.Q2 import question_2
question_2(df)
# Out:
# "En 2022, il y avait 12 candidats à l'élection présidentielle."

# %%
# Question 3
from great_tables import GT
table_voix = question_3(df)
(
    GT(table_voix)
    .tab_header(title="Elections", subtitle=f"Résultats du premier tour (10 avril 2022)")
    .fmt_number(columns=["Nombre de vote (total)", "Score(% exprimé)"])
)
# Out:
# GT(_tbl_data=                 candidat  Nombre de vote (total)  Score(% exprimé)
# 1         Emmanuel MACRON                 9783058         27.845822
# 5           Marine LE PEN                 8133828         23.151568
# 4      Jean-Luc MÉLENCHON                 7712520         21.952386
# 11           Éric ZEMMOUR                 2485226          7.073776
# 9        Valérie PÉCRESSE                 1679001          4.778993
# 10          Yannick JADOT                 1627853          4.633409
# 3           Jean LASSALLE                 1101387          3.134912
# 2          Fabien ROUSSEL                  802422          2.283959
# 7   Nicolas DUPONT-AIGNAN                  725176          2.064091
# 0            Anne HIDALGO                  616478          1.754701
# 8         Philippe POUTOU                  268904          0.765390
# ...

# %% [markdown]
# 2. Comparaison des scores départements aux moyennes nationales

# %%
# Question 4

# %%
# Question 5

# %%
# Question 6

# %%
# Question 7

# %% [markdown]
# 3.Un peu de cartographie

# %%
# Question 8
