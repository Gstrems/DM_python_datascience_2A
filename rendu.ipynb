# %% [markdown]
# Rendu Intermédiaire Python pour la datascience - Gabriel Stremsdoerfer

# %%
# importation données
import pandas as pd
df = pd.read_csv(
    'https://www.data.gouv.fr/fr/datasets/r/182268fc-2103-4bcb-a850-6cf90b02a9eb'
)
df
# Out:
# /tmp/ipykernel_36894/2336434942.py:3: DtypeWarning: Columns (0: prenom) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
#        code_departement              libelle_departement  code_commune  \
# 0                    01                              Ain             1
# 1                    01                              Ain             2
# 2                    01                              Ain             4
# 3                    01                              Ain             5
# 4                    01                              Ain             6
# ...                 ...                              ...           ...
# 528670      fr_etranger  Français établis hors de France           229
# 528671      fr_etranger  Français établis hors de France           231
# 528672      fr_etranger  Français établis hors de France           233
# 528673      fr_etranger  Français établis hors de France           234
# 528674      fr_etranger  Français établis hors de France           235
#
#                 libelle_commune    prenom      nom  voix
# 0       L'Abergement-Clémenciat  Nathalie  ARTHAUD     3
# 1         L'Abergement-de-Varey  Nathalie  ARTHAUD     2
# 2             Ambérieu-en-Bugey  Nathalie  ARTHAUD    38
# 3           Ambérieux-en-Dombes  Nathalie  ARTHAUD     8
# 4                       Ambléon  Nathalie  ARTHAUD     0
# ...                         ...       ...      ...   ...
# 528670                   Zurich       NaN     nuls    31
# 528671                   Taipei       NaN     nuls     2
# 528672             Nour-Soultan       NaN     nuls     0
# 528673                Monterrey       NaN     nuls     2
# 528674         Bahamas (Nassau)       NaN     nuls     0
#
# [528675 rows x 7 columns]

# %% [markdown]
# 1.Exploration générale

# %%
# Question 1
from code_exo.exo1.Q1 import question_1
question_1(df)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Question 1
#       2 from code_exo.exo1.Q1 import question_1
# ----> 3 question_1(df)
#       4 df
#
# File ~/work/DM_python_datascience_2A/code_exo/exo1/Q1.py:2, in question_1(df)
#       1 def question_1(df):
# ----> 2     df['prenom'] = df['prenom'].replace(['NaN', 'nan', ''], pd.NA) # on s'assure que les nan deviennent bien des NA
#       3     df['prenom'] = df['prenom'].fillna('NR') # on les remplace par une modalité en soi, pour ne pas perdre l'info de 'nom' quand on créera 'candidat'
#       4     df['code_commune'] = df['code_commune'].astype(str).str.zfill(3)
#
# NameError: name 'pd' is not defined

# %%
# Question 2
from code_exo.exo1.Q2 import question_2
question_2(df)
# Out:
# "En 2022, il y avait 12 candidats à l'élection présidentielle."

# %%
# Question 3
from code_exo.exo1.Q3 import question_3
question_3(df)
# Out:
# <StringArray>
# [      'ARTHAUD',       'ROUSSEL',        'MACRON',      'LASSALLE',
#         'LE PEN',       'ZEMMOUR',     'MÉLENCHON',       'HIDALGO',
#          'JADOT',      'PÉCRESSE',        'POUTOU', 'DUPONT-AIGNAN',
#    'abstentions',        'blancs',          'nuls']
# Length: 15, dtype: str

# %% [markdown]
# 2. Comparaison des scores départements aux moyennes nationales

# %%
df['voix'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['voix'].sum()
#
# NameError: name 'df' is not defined

# %%
# Question 4
df.loc[ ~df['candidat'].isin(['NR nuls', 'NR abstentions', 'NR blancs']),'voix'].sum()
# Out:
# np.int64(48747876)

# %%
# Question 5

# %%
# Question 6

# %%
# Question 7

# %% [markdown]
# 3.Un peu de cartographie

# %%
# Question 8
